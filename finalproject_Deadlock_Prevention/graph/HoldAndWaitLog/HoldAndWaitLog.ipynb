# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/"+'2021-12-20_12_45_22DeadLockPreventionUsingHoldAndWaitLog.txt')
data.columns = ['time', 'running']

# %%
data.head()
# Out:
#    time  running
# 0   236       30
# 1   346       24
# 2   456       25
# 3   567       18
# 4   678       24

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time     402 non-null    int64
#  1   running  402 non-null    int64
# dtypes: int64(2)
# memory usage: 6.4 KB

# %%
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['running'])
plt.xlabel('time')
plt.ylabel('running')
plt.yticks(range(0, 35, 5))
plt.show()

# %%
data['running'].mean()
# Out:
# 16.761194029850746
