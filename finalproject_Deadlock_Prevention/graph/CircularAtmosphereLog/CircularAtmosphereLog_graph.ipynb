# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/"+'2021-12-20_12_19_24DeadLockPreventionUsingCircularAtmosphereLog.txt')
data.columns = ['time', 'running']

# %%
data.head()
# Out:
#    time  running
# 0   253       18
# 1   364       11
# 2   474        4
# 3   584        7
# 4   694        9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time     937 non-null    int64
#  1   running  937 non-null    int64
# dtypes: int64(2)
# memory usage: 14.8 KB

# %%
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['running'])
plt.xlabel('time')
plt.ylabel('running')
plt.yticks(range(0, 20))
plt.show()

# %%
data['running'].describe()
# Out:
# count    937.000000
# mean       7.338314
# std        2.382664
# min        0.000000
# 25%        6.000000
# 50%        7.000000
# 75%        9.000000
# max       18.000000
# Name: running, dtype: float64
