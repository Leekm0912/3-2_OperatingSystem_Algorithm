# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('2021-12-20_11_13_57DeadLockPreventionUsingCircularAtmosphereLog.txt')
data.columns = ['time', 'run']

# %%
data.head()
# Out:
#    time  run
# 0   210    5
# 1   320    3
# 2   429    1
# 3   538    1
# 4   648    2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    650 non-null    int64
#  1   run     650 non-null    int64
# dtypes: int64(2)
# memory usage: 10.3 KB

# %%
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['run'])
plt.xlabel('time')
plt.ylabel('running')
plt.yticks(range(1, 6))
plt.show()
