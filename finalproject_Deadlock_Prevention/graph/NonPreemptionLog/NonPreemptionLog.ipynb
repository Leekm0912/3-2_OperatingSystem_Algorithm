# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = '2021-12-20_20_57_55DeadLockPreventionUsingNonPreemptionLog.txt'
data = pd.read_csv("data/"+file)
data.columns = ['time', 'running']

# %%
data.head()
# Out:
#    time  running
# 0   254       20
# 1   387       15
# 2   547       16
# 3   709       17
# 4   824       23

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time     327 non-null    int64
#  1   running  327 non-null    int64
# dtypes: int64(2)
# memory usage: 5.2 KB

# %%
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['running'])
plt.xlabel('time')
plt.ylabel('running')
plt.yticks(range(0, 40, 10))
plt.show()

# %%
data['running'].describe()
# Out:
# count    327.000000
# mean      26.082569
# std        5.026546
# min        0.000000
# 25%       25.000000
# 50%       28.000000
# 75%       29.000000
# max       30.000000
# Name: running, dtype: float64
