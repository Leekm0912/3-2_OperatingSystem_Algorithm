# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = '2021-12-20_12_29_42DeadLockPreventionUsingNonPreemptionLog.txt'
data = pd.read_csv("data/"+file)
data.columns = ['time', 'running']

# %%
data.head()
# Out:
#    time  running
# 0   225      144
# 1   333       93
# 2   445      103
# 3   552       99
# 4   661      107

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time     52 non-null     int64
#  1   running  52 non-null     int64
# dtypes: int64(2)
# memory usage: 960.0 bytes

# %%
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['running'])
plt.xlabel('time')
plt.ylabel('running')
plt.yticks(range(0, 170, 10))
plt.show()

# %%
data['running'].mean()
# Out:
# 131.78846153846155
