# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = '2021-12-20_12_38_38DeadLockPreventionUsingNonPreemptionLog.txt'
data = pd.read_csv("data/"+file)
data.columns = ['time', 'running']

# %%
data.head()
# Out:
#    time  running
# 0   238      150
# 1   348      149
# 2   457      140
# 3   565      130
# 4   676      129

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time     51 non-null     int64
#  1   running  51 non-null     int64
# dtypes: int64(2)
# memory usage: 944.0 bytes

# %%
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['running'])
plt.xlabel('time')
plt.ylabel('running')
plt.yticks(range(0, 170, 10))
plt.show()

# %%
data['running'].mean()
# Out:
# 135.27450980392157
